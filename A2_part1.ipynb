# %%
import numpy as np
import matplotlib.pyplot as plt


x = [-2,-1,0,1,2]
x_added = [-1.75,-1.5,-1.25,-0.75,-0.5,-0.25,0.25,0.5,0.75,1.25,1.5,1.75]
y = [4,1,5,1,4]
y_added = [3.25,2.5,1.75,2,3,4,4,3,2,1.75,2.5,3.25]
for original_x in x:
    plt.scatter(x, y,c="b")
for new_x in x_added:
    plt.scatter(x_added, y_added,c="r")   
plt.vlines(x=-2, ymin=-1, ymax=4)
plt.vlines(x=-1.75, ymin=-1, ymax=3.25)
plt.vlines(x=-1.5, ymin=-1, ymax=2.5)
plt.vlines(x=-1.25, ymin=-1, ymax=1.75)
plt.vlines(x=-1, ymin=-1, ymax=1)
plt.vlines(x=-0.75, ymin=-1, ymax=2)
plt.vlines(x=-.5, ymin=-1, ymax=3)
plt.vlines(x=-.25, ymin=-1, ymax=4)
plt.vlines(x=0, ymin=-1, ymax=5)
plt.vlines(x=.25, ymin=-1, ymax=4)
plt.vlines(x=.5, ymin=-1, ymax=3)
plt.vlines(x=.75, ymin=-1, ymax=2)
plt.vlines(x=1, ymin=-1, ymax=1)
plt.vlines(x=1.25, ymin=-1, ymax=1.75)
plt.vlines(x=1.5, ymin=-1, ymax=2.5)
plt.vlines(x=1.75, ymin=-1, ymax=3.25)
plt.vlines(x=2, ymin=-1, ymax=4)
plt.show()
